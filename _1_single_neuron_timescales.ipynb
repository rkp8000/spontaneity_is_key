# %%
# %matplotlib inline
from figures import down_sampled_interval_variation_vs_chance

# %%
down_sampled_interval_variation_vs_chance(
    SEED=0,
    
    DATA_DIRECTORY='/Users/rkp/Dropbox/luis_data',
    DATA_FILENAME='trace_foopsi_spon.mat',
    
    DT_ORIGINAL=0.25,
    DOWN_SAMPLE_TIMESCALE=1,
    
    SPIKE_THRESHOLD='random',
    
    N_SHUFFLES=100,
    
    EXAMPLE_CELL_PROBABILITIES=84,
    EXAMPLE_CELL_PROBABILITIES_N_SECONDS=70,
    
    SPIKE_TRAIN_CELLS=range(80),
    SPIKE_TRAINS_N_SECONDS=1000,
    
    FIG_SIZE=(15, 18),
    FONT_SIZE=16,
)
# Out:
# mean coefficient of variation: 1.11235546135
# std coefficient of variation: 0.238130766866
# sem coefficeint of variation: 0.0217382654414
# /Users/rkp/anaconda/lib/python2.7/site-packages/matplotlib/figure.py:1744: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
